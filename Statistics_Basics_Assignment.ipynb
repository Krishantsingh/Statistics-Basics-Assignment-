# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishantsingh/Statistics-Basics-Assignment-/blob/main/Statistics_Basics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales.
#
#  = There are major two types of data, that are Qualitative Data and Quantitative Data.
#
#     i. Qualitative Data :
#
#         - This type of data describes characteristics or qualities and is not numerical by nature. Like rank, grade etc.
#
#     ii. Qualitative Data :
#
#         - This type of data represents quantities and can be measured in terms of number. These data are used to calculate mean, median,

# %% [markdown]
# i. Nominal Scale:
#
#     - Under this data is categorized without any order. Like blood group, gender, colours etc.
#
# ii. Ordinal Scale:
#
#    - Under this data is categoirized with a proper order. Like rank, grade and salary etc.
#
# iii. interval scale:
#
#    - Under this data is numeric with consistent intervals between values, but there is no true zero point.
#
# iv. Ratio Scale :
#
#    - Under this, data is numeric with consistent intervals between values and it has a true zero point.

# %% [markdown]
# 2.  What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate??
#
#    = Measures of central tendency summarize a data set by identifying a single value that represents the "center" or typical value. The three main measures are mean, median, and mode. Each is suitable for different types of data and purposes.

# %% [markdown]
# i. Mean :
#
#    -  The mean is the sum of all values divided by the number of values. It is denoted by x bar. It is used when we have to know the average of any data.
#
# ii. median:
#
#   - The middle value when the data is ordered is known as median.It is denoted by (md). It is used when we have to know the mid point of any ordered data.
#
# iii. Mode:
#
#   - The value that is most frequent in a data set. It is used when we have to know the most repeated element in a data set.

# %% [markdown]
# 3.  Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
#   = Dispersion refers to the degree of spread or variability in a data set. It describes how far individual data points are from each other and the central tendency.
#
#
#   * Variance:
#
#     - Variance measures the average squared deviation of each data point from the mean.
#
#
#   * Standard Deviation:
#
#    - he standard deviation (SD) is the square root of the variance. It represents the average distance of each data point from the mean in the same units as the data.

# %% [markdown]
# 4.  What is a box plot, and what can it tell you about the distribution of data?
#
#    = A box plot is a graphical representation of a data set that summarizes its distribution using five key summary statistics that are Minimum, First Quartile(Q1), Median(Q2), Third Quartile(Q3), Maximum etc.

# %% [markdown]
# 5. Discuss the role of random sampling in making inferences about populations.
#
#   = It is a type of data sampling method in which every member of population has equal chance of being selected in the sample data. Each member has 1/12 change of being selected in the sample.

# %% [markdown]
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#
#   = Skewness measures the asymmetry of a data distribution around its mean.  A perfectly symmetrical distribution has a skewness of 0. When a distribution is not symmetrical, it is said to be skewed, which means that the data's values are distributed more heavily on one side of the mean than the other.

# %% [markdown]
# 7.  What is the interquartile range (IQR), and how is it used to detect outliers?
#
#   = The Interquartile Range (IQR) is a measure of statistical dispersion that represents the range of the middle 50% of a data set. It is calculated as the difference between the third quartile (
# 𝑄
# 3
# Q3) and the first quartile (
# 𝑄
# 1
# Q1):
#
# Inter Quartile Range(IQR) is used to detect outliers based on the following points:
#
# i. Lower Fence : Q1 - 1.5 * IQR
#
# ii. Upper Fence : Q3 - 1.5 * IQR
#
# The data points below the lower fence and above the upper fence.

# %% [markdown]
# 8. Discuss the conditions under which the binomial distribution is used.
#
#   = The binomial distribution is used to model situations where we are repeating same experiment multiples times and we are interested to count how many times a specific outcome oocur.

# %% [markdown]
# 9.  Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#
#   = some major properties of normal distribution are as follow,
#
#     * Symmetrical Shape
#
#     * Mean, Median, and Mode are Equal
#
#     * Bell-Shaped Curve
#
#     * Tails Extend Infinitely etc.
#
#   Some major properties of Empirical rule are as foolow,
#
#     * Approximately 68% of the data falls within 1 standard deviation of the mean.
#
#     * About 95% of the data falls within 2 standard deviations of the mean.
#
#     * Nearly 99.7% of the data falls within 3 standard deviations of the mean.

# %% [markdown]
# 10. . Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#
#     = Real-Life Example of a Poisson Process
#
#       - A customer service call center receives an average of 5 calls per hour. You want to calculate the probability of receiving exactly 3 calls in a given hour.

# %% [markdown]
# λ=5 (average number of calls per hour)
#
# k=3 (specific number of calls we are interested in).
#
# Calculating Probability
#
# The probability will be 14.005

# %% [markdown]
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#
#   = A random variable is a numerical outcome of a random process or experiment. It takes different values based on the result of an uncertain event or process.
#
# *  Discrete Random Variables:
#
#   - A discrete random variable is a variable that can only take a countable number of distinct values. These values are often integers or whole numbers, and there are gaps between them.
#
# * Continuous Random Variable:
#
#   - A continuous random variable is a variable that can take any value within a certain range, and the values are not countable. These variables can have infinite possible values, including decimals or fractions.

# %% [markdown]
# 12.  Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#
#    =

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.cov(numeric_only = True) # here range can be any value
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
df.corr(numeric_only = True) #r here range is -1 to 1
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# Conclusion : Covariance range can be anythin -∞ to ∞
